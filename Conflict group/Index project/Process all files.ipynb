# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load in sooooo many datasets

#electricity by region
electricity_ssp1 = pd.read_csv("elec_by_region_ssp1.csv")
electricity_ssp2 = pd.read_csv("elec_by_region_ssp2.csv")
electricity_ssp3 = pd.read_csv("elec_by_region_ssp3.csv")
electricity_ssp4 = pd.read_csv("elec_by_region_ssp4.csv")
electricity_ssp5 = pd.read_csv("elec_by_region_ssp5.csv")
electricity_ndc = pd.read_csv("ndc_elec_query.csv")

population_ssp1 = pd.read_csv("pop_by_region_ssp1.csv")
population_ssp2 = pd.read_csv("pop_by_region_ssp2.csv")
population_ssp3 = pd.read_csv("pop_by_region_ssp3.csv")
population_ssp4 = pd.read_csv("pop_by_region_ssp4.csv")
population_ssp5 = pd.read_csv("pop_by_region_ssp5.csv")
population_ndc = pd.read_csv("ndc_pop_query.csv")

energy_consum_ssp1 = pd.read_csv("ssp1_energy_consum_by_region.csv")
energy_consum_ssp2 = pd.read_csv("ssp2_energy_consum_by_region.csv")
energy_consum_ssp3 = pd.read_csv("ssp3_energy_consum_by_region.csv")
energy_consum_ssp4 = pd.read_csv("ssp4_energy_consum_by_region.csv")
energy_consum_ssp5 = pd.read_csv("ssp5_energy_consum_by_region.csv")
energy_consum_ndc = pd.read_csv("ndc_energy_consum_by_region.csv")

#food_consum_ssp1 = pd.read_csv("ssp1_food_con.csv")
#food_consum_ssp2 = pd.read_csv("ssp2_food_con.csv")
#food_consum_ssp3 = pd.read_csv("ssp3_food_con.csv")
#food_consum_ssp4 = pd.read_csv("ssp4_food_con.csv")
#food_consum_ssp5 = pd.read_csv("ssp5_food_con.csv")
#food_consum_ndc = pd.read_csv(

food_consum_by_type_ssp1 = pd.read_csv("ssp1_food_consumption_by_type.csv")
food_consum_by_type_ssp2 = pd.read_csv("ssp2_food_consumption_by_type.csv")
food_consum_by_type_ssp3 = pd.read_csv("ssp3_food_consumption_by_type.csv")
food_consum_by_type_ssp4 = pd.read_csv("ssp4_food_consumption_by_type.csv")
food_consum_by_type_ssp5 = pd.read_csv("ssp5_food_consumption_by_type.csv")
food_consum_by_type_ndc = pd.read_csv("ndc_food_consumption_by_type.csv")

food_price_ssp1 = pd.read_csv("ssp1_food_price.csv")
food_price_ssp2 = pd.read_csv("ssp2_food_price.csv")
food_price_ssp3 = pd.read_csv("ssp3_food_price.csv")
food_price_ssp4 = pd.read_csv("ssp4_food_price.csv")
food_price_ssp5 = pd.read_csv("ssp5_food_price.csv")
food_price_ndc = pd.read_csv("ndc_food_price_query.csv")

gdp_ssp1 = pd.read_csv("ssp1_gdp_query.csv")
gdp_ssp2 = pd.read_csv("ssp2_gdp_query.csv")
gdp_ssp3 = pd.read_csv("ssp3_gdp_query.csv")
gdp_ssp4 = pd.read_csv("ssp4_gdp_query.csv")
gdp_ssp5 = pd.read_csv("ssp5_gdp_query.csv")
gdp_ndc = pd.read_csv("ndc_total_gdp_query.csv")

gw_resources_ssp1 = pd.read_csv("ssp1_groundwater_query.csv")
gw_resources_ssp2 = pd.read_csv("ssp2_groundwater_query.csv")
gw_resources_ssp3 = pd.read_csv("ssp3_groundwater_query.csv")
gw_resources_ssp4 = pd.read_csv("ssp4_groundwater_query.csv")
gw_resources_ssp5 = pd.read_csv("ssp5_groundwater_query.csv")
gw_resources_ndc = pd.read_csv("ndc_groundwater_query.csv")

water_withdrawals_ssp1 = pd.read_csv("ssp1_water_withdrawals_by_region.csv")
water_withdrawals_ssp2 = pd.read_csv("ssp2_water_withdrawals_by_region.csv")
water_withdrawals_ssp3 = pd.read_csv("ssp3_water_withdrawals_by_region.csv")
water_withdrawals_ssp4 = pd.read_csv("ssp4_water_withdrawals_by_region.csv")
water_withdrawals_ssp5 = pd.read_csv("ssp5_water_withdrawals_by_region.csv")
water_withdrawals_ndc = pd.read_csv("ndc_water_withdrawals_by_region.csv")

water_consum_by_region_ssp1 = pd.read_csv("wat_consum_by_region_ssp1.csv")
water_consum_by_region_ssp2 = pd.read_csv("wat_consum_by_region_ssp2.csv")
water_consum_by_region_ssp3 = pd.read_csv("wat_consum_by_region_ssp3.csv")
water_consum_by_region_ssp4 = pd.read_csv("wat_consum_by_region_ssp4.csv")
water_consum_by_region_ssp5 = pd.read_csv("wat_consum_by_region_ssp5.csv")
water_consum_by_region_ndc = pd.read_csv("ndc_water_con_by_region.csv")

gdp_total_ssp1 = pd.read_csv("ssp1_total_gdp_query.csv")
gdp_total_ssp2 = pd.read_csv("ssp2_total_gdp_query.csv")
gdp_total_ssp3 = pd.read_csv("ssp3_total_gdp_query.csv")
gdp_total_ssp4 = pd.read_csv("ssp4_total_gdp_query.csv")
gdp_total_ssp5 = pd.read_csv("ssp5_total_gdp_query.csv")
gdp_total_ndc = pd.read_csv("ndc_total_gdp_query.csv")

elec_prices_ssp1 = pd.read_csv("ssp1_elec_prices_by_sector.csv")
elec_prices_ssp2 = pd.read_csv("ssp2_elec_prices_by_sector.csv")
elec_prices_ssp3 = pd.read_csv("ssp3_elec_prices_by_sector.csv")
elec_prices_ssp4 = pd.read_csv("ssp4_elec_prices_by_sector.csv")
elec_prices_ssp5 = pd.read_csv("ssp5_elec_prices_by_sector.csv")
elec_prices_ndc = pd.read_csv("ndc_elec_prices_by_sector.csv")

# %%
def add_ssp_col(df, ssp):
    df['ssp'] = ssp
    return df

list_ssp1 = [electricity_ssp1, population_ssp1, energy_consum_ssp1, food_consum_by_type_ssp1, food_price_ssp1, gdp_ssp1, gw_resources_ssp1, water_withdrawals_ssp1, water_consum_by_region_ssp1, gdp_total_ssp1, elec_prices_ssp1]
list_ssp2 = [electricity_ssp2, population_ssp2, energy_consum_ssp2, food_consum_by_type_ssp2, food_price_ssp2, gdp_ssp2, gw_resources_ssp2, water_withdrawals_ssp2, water_consum_by_region_ssp2, gdp_total_ssp2, elec_prices_ssp2]
list_ssp3 = [electricity_ssp3, population_ssp3, energy_consum_ssp3, food_consum_by_type_ssp3, food_price_ssp3, gdp_ssp3, gw_resources_ssp3, water_withdrawals_ssp3, water_consum_by_region_ssp3, gdp_total_ssp3, elec_prices_ssp3]
list_ssp4 = [electricity_ssp4, population_ssp4, energy_consum_ssp4, food_consum_by_type_ssp4, food_price_ssp4, gdp_ssp4, gw_resources_ssp4, water_withdrawals_ssp4, water_consum_by_region_ssp4, gdp_total_ssp4, elec_prices_ssp4]
list_ssp5 = [electricity_ssp5, population_ssp5, energy_consum_ssp5, food_consum_by_type_ssp5, food_price_ssp5, gdp_ssp5, gw_resources_ssp5, water_withdrawals_ssp5, water_consum_by_region_ssp5, gdp_total_ssp5, elec_prices_ssp5]
list_ndc = [electricity_ndc, population_ndc, energy_consum_ndc, food_consum_by_type_ndc, food_price_ndc, gdp_ndc, gw_resources_ndc, water_withdrawals_ndc, water_consum_by_region_ndc, gdp_total_ndc, elec_prices_ndc]


for i in range(0, len(list_ssp1)):
    list_ssp1[i] = add_ssp_col(list_ssp1[i], 1)
    list_ssp2[i] = add_ssp_col(list_ssp2[i], 2)
    list_ssp3[i] = add_ssp_col(list_ssp3[i], 3)
    list_ssp4[i] = add_ssp_col(list_ssp4[i], 4)
    list_ssp5[i] = add_ssp_col(list_ssp5[i], 5)
    list_ndc[i] = add_ssp_col(list_ndc[i], 0)

electricity_full = pd.concat([electricity_ssp1, electricity_ssp2, electricity_ssp3, electricity_ssp4, electricity_ssp5, electricity_ndc], ignore_index = True)
population_full = pd.concat([population_ssp1, population_ssp2, population_ssp3, population_ssp4, population_ssp5, population_ndc], ignore_index = True)
energy_consum_full = pd.concat([energy_consum_ssp1, energy_consum_ssp2, energy_consum_ssp3, energy_consum_ssp4, energy_consum_ssp5, energy_consum_ndc], ignore_index = True)
#food_consum_full = pd.concat([food_consum_ssp1, food_consum_ssp2, food_consum_ssp3, food_consum_ssp4, food_consum_ssp5], ignore_index = True)
food_consum_by_type_full = pd.concat([food_consum_by_type_ssp1, food_consum_by_type_ssp2, food_consum_by_type_ssp3, food_consum_by_type_ssp4, food_consum_by_type_ssp5, food_consum_by_type_ndc], ignore_index = True)
food_price_full = pd.concat([food_price_ssp1, food_price_ssp2, food_price_ssp3, food_price_ssp4, food_price_ssp5, food_price_ndc], ignore_index = True)
gdp_full = pd.concat([gdp_ssp1, gdp_ssp2, gdp_ssp3, gdp_ssp4, gdp_ssp5, gdp_ndc], ignore_index = True)
gw_resources_full = pd.concat([gw_resources_ssp1, gw_resources_ssp2, gw_resources_ssp3, gw_resources_ssp4, gw_resources_ssp5, gw_resources_ndc], ignore_index = True)
water_withdrawals_full = pd.concat([water_withdrawals_ssp1, water_withdrawals_ssp2, water_withdrawals_ssp3, water_withdrawals_ssp4, water_withdrawals_ssp5, water_withdrawals_ndc], ignore_index = True)
water_consum_by_region_full = pd.concat([water_consum_by_region_ssp1, water_consum_by_region_ssp2, water_consum_by_region_ssp3, water_consum_by_region_ssp4, water_consum_by_region_ssp5, water_consum_by_region_ndc], ignore_index = True)
gdp_total_full = pd.concat([gdp_total_ssp1, gdp_total_ssp2, gdp_total_ssp3, gdp_total_ssp4, gdp_total_ssp5, gdp_total_ndc], ignore_index = True)
elec_price_full = pd.concat([elec_prices_ssp1, elec_prices_ssp2, elec_prices_ssp3, elec_prices_ssp4, elec_prices_ssp5, elec_prices_ndc], ignore_index = True)



#now units
electricity_full = electricity_full.rename(columns = {'value': 'Electricity (EJ)'})
electricity_full = electricity_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(electricity_full.loc[electricity_full['region'] == 'USA'])
population_full = population_full.rename(columns = {'value': 'Population (Thousands)'})
population_full = population_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(population_full.loc[population_full['region'] == 'USA'])
energy_consum_full = energy_consum_full.rename(columns = {'value': 'Energy Consumption (EJ)'})
energy_consum_full = energy_consum_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(energy_consum_full.loc[energy_consum_full['region'] == 'USA'])
#food_consum_full = food_consum_full.rename(columns = {'value': 'Food Consumption (Pcal)'})
#food_consum_full = food_consum_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
#print(food_consum_full.loc[food_consum_full['region'] == 'USA'])
food_consum_by_type_full = food_consum_by_type_full.rename(columns = {'value': 'Food Consumption By Type (Pcal)'})
food_consum_by_type_full = food_consum_by_type_full.drop(columns = ["rundate", "Units", "Unnamed: 0", "sector"])
print(food_consum_by_type_full.loc[food_consum_by_type_full['region'] == 'USA'])
food_price_full = food_price_full.rename(columns = {'value': 'Food Price (2005$/Mcal/day)', 'input': 'Food Price Staple/Nonstaple'})
food_price_full = food_price_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(food_price_full.loc[food_price_full['region'] == 'USA'])
gdp_full = gdp_full.rename(columns = {'value': 'GDP per capita (million 1990$)'})
gdp_full = gdp_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(gdp_full.loc[gdp_full['region'] == 'USA'])
gw_resources_full = gw_resources_full.rename(columns = {'value': 'Water Resources (km^3)'})
gw_resources_full = gw_resources_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(gw_resources_full.loc[gw_resources_full['region'] == 'USA'])
water_withdrawals_full = water_withdrawals_full.rename(columns = {'value': 'Water Withdrawals (km^3)'})
water_withdrawals_full = water_withdrawals_full .drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(water_withdrawals_full.loc[water_withdrawals_full['region'] == 'USA'])
water_consum_by_region_full = water_consum_by_region_full.rename(columns = {'value': 'Municipal Water Consumption (km^3)', 'input': 'input water consumption by region'})
water_consum_by_region_full = water_consum_by_region_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(water_consum_by_region_full.loc[water_consum_by_region_full['region'] == 'USA'])
gdp_total_full = gdp_total_full.rename(columns = {'value': 'GDP (Million 1990$)'})
gdp_total_full= gdp_total_full.drop(columns = ["rundate", "Units", "Unnamed: 0"])
print(gdp_total_full.loc[gdp_total_full['region'] == 'USA'])
elec_price_full = elec_price_full.rename(columns = {'value': 'Electricity Price (1975$/GJ)'})
elec_price_full = elec_price_full .drop(columns = ["rundate", "Units", "Unnamed: 0"])
# Out:
#                scenario region                 sector         input  year  \
# 21570         Reference    USA  H2 central production  elect_td_ind  2025
# 21571         Reference    USA  H2 central production  elect_td_ind  2030
# 21572         Reference    USA  H2 central production  elect_td_ind  2035
# 21573         Reference    USA  H2 central production  elect_td_ind  2040
# 21574         Reference    USA  H2 central production  elect_td_ind  2045
# ...                 ...    ...                    ...           ...   ...
# 134265  PolicyReference    USA      trn_shipping_intl  elect_td_trn  2080
# 134266  PolicyReference    USA      trn_shipping_intl  elect_td_trn  2085
# 134267  PolicyReference    USA      trn_shipping_intl  elect_td_trn  2090
# 134268  PolicyReference    USA      trn_shipping_intl  elect_td_trn  2095
# 134269  PolicyReference    USA      trn_shipping_intl  elect_td_trn  2100
#
#         Electricity (EJ)  ssp
# 21570           0.000727    1
# ...

# %%
print(gw_resources_full['subresource'].unique())
# Out:
# ['groundwater grade hist' 'groundwater grade1' 'groundwater grade10'
#  'groundwater grade11' 'groundwater grade12' 'groundwater grade13'
#  'groundwater grade14' 'groundwater grade15' 'groundwater grade16'
#  'groundwater grade17' 'groundwater grade18' 'groundwater grade19'
#  'groundwater grade2' 'groundwater grade20' 'groundwater grade3'
#  'groundwater grade4' 'groundwater grade5' 'groundwater grade6'
#  'groundwater grade7' 'groundwater grade8' 'groundwater grade9' 'runoff']

# %%
#add more work here
food_price_full = food_price_full.loc[food_price_full['Food Price Staple/Nonstaple'] =='FoodDemand_Staples']

#elec shortenine
electricity_full_cooling = electricity_full.loc[electricity_full['sector'] == 'resid cooling']
electricity_full_resid_other = electricity_full.loc[electricity_full['sector'] == 'resid others']
electricity_full_cooling = electricity_full_cooling.rename(columns = {'Electricity (EJ)': 'Electricity Cooling (EJ)'})
electricity_full_cooling_1 = electricity_full_cooling.rename(columns = {'Electricity (EJ)': 'Electricity Cooling (EJ)'})
electricity_full_resid_other = electricity_full_resid_other.rename(columns = {'Electricity (EJ)': 'Electricity Residential (EJ)'})
electricity_full_cooling.drop(["sector", "input"], axis = 1)
electricity_full_resid_other.drop(["sector", "input"], axis = 1)
electricity_full_short = electricity_full_cooling.merge(electricity_full_resid_other, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
electricity_full_short["Total Residential Electricity Consumption (EJ)"] = electricity_full_short['Electricity Cooling (EJ)'] + electricity_full_short['Electricity Residential (EJ)']

def make_small_dfs(heading, name, base):
    electricity_full_small = electricity_full.loc[electricity_full['sector'] == heading]
    #print(len(electricity_full_small))
    electricity_full_small = electricity_full_small.rename(columns = {'Electricity (EJ)': 'Electricity (EJ)' + name})
    electricity_full_small= electricity_full_small.drop(["sector", "input"], axis = 1)
    electricity_full_cooling_1 = pd.merge(base, electricity_full_small, on=['region', 'ssp', 'year', 'scenario'], how='outer').fillna(0)
    #electricity_full_cooling_1 = electricity_full_cooling.merge(electricity_full_small, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
    return electricity_full_cooling_1

heading_list = electricity_full["sector"].unique()
for i in range(0, len(heading_list)):
    #print(i)
    electricity_full_cooling_1 = make_small_dfs(heading_list[i], heading_list[i], electricity_full_cooling_1)
    #print(electricity_full_cooling_1)
    
    
#print('elec full short')
#print(electricity_full_short)
#electricity_sum = electricity_full.groupby(["region", "year"], as_index = False).sum()
#electricity_sum = electricity_sum.drop(columns = ["sector", "input"], axis = 1)
#electricity_sum['scenario'] = 'Reference'
#electricity_sum = electricity_sum.rename(columns = {'Electricity (EJ)': 'Total Electricity Consumption (EJ)'})
#print('elec sum')
#print(electricity_sum)
#electricity_combined = electricity_full_short.merge(electricity_sum, how = 'outer')
#print('elec combined')
#print(electricity_combined)



#population is population - no other adjustments needed

#energy consumption
#traditional biomass, fuel

energy_consum_full_short = energy_consum_full.loc[energy_consum_full["fuel"] == "a oil"]
energy_consum_full_short  = energy_consum_full_short .rename(columns = {'Energy Consumption (EJ)': 'Energy Consumption (EJ)a oil'})
energy_consum_full_short.drop(["fuel"], axis = 1)

def make_small_dfs(heading, name, base):
    energy_consum_full_small = energy_consum_full.loc[energy_consum_full['fuel'] == heading]
    print(len(energy_consum_full_small))
    energy_consum_full_small = energy_consum_full_small.rename(columns = {'Energy Consumption (EJ)': 'Energy Consumption (EJ)' + name})
    energy_consum_full_small= energy_consum_full_small.drop(["fuel"], axis = 1)
    energy_consum_full_short = pd.merge(base, energy_consum_full_small, on=['region', 'ssp', 'year', 'scenario'], how='outer').fillna(0)
    #electricity_full_cooling_1 = electricity_full_cooling.merge(electricity_full_small, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
    return energy_consum_full_short

heading_list = energy_consum_full["fuel"].unique()
for i in range(1, len(heading_list)):
    #print(i)
    energy_consum_full_short = make_small_dfs(heading_list[i], heading_list[i], energy_consum_full_short)
    #print(energy_consum_full_short)

#food consum full - - take apart, replace columns and call it a day
#print(food_consum_by_type_full)
food_demand_nonstaples = food_consum_by_type_full.loc[food_consum_by_type_full['output']== 'FoodDemand_NonStaples']
food_demand_staples = food_consum_by_type_full.loc[food_consum_by_type_full['output']== 'FoodDemand_Staples']
food_demand_nonstaples = food_demand_nonstaples.rename(columns = {'Food Consumption By Type (Pcal)': 'Food Consumption By Type (Pcal) NonStaples'})
food_demand_staples = food_demand_staples.rename(columns = {'Food Consumption By Type (Pcal)': 'Food Consumption By Type (Pcal) Staples'})
food_demand_staples.drop(["output"], axis = 1)
food_demand_nonstaples.drop(["output"], axis = 1)
food_consum_by_type_full = food_demand_nonstaples.merge(food_demand_staples, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
food_consum_by_type_full["Total Food Consumption (Pcal)"] = food_consum_by_type_full['Food Consumption By Type (Pcal) Staples'] + food_consum_by_type_full['Food Consumption By Type (Pcal) NonStaples']
#print(food_consum_by_type_full)

#food_price_full - take apart, replace columns and call it a day


#gdp_full - as is

#water_withdrawals_ful- as is

#water consumption by region
water_consum_by_region_full_short= water_consum_by_region_full.loc[water_consum_by_region_full['input water consumption by region'] == 'water_td_muni_C']


#groundwater resources
#we need to separate runoff vs gw

#water_resources_runoff = gw_resources_full.loc[gw_resources_full['subresource'] == "runoff"]
#water_resources_gw = gw_resources_full.loc[gw_resources_full['subresource'] != "runoff"]
water_resources_gw_short = gw_resources_full.loc[gw_resources_full["subresource"] == "groundwater grade hist"]
water_resources_gw_short = water_resources_gw_short.rename(columns = {'Water Resources (km^3)': 'Water Resources (km^3) grade hist'})
water_resources_gw_short.drop(["subresource"], axis = 1)

def make_small_dfs_water(heading, name, base):
    water_resources_gw_small = gw_resources_full.loc[gw_resources_full['subresource'] == heading]
    print(len(water_resources_gw_small))
    water_resources_gw_small = water_resources_gw_small.rename(columns = {'Water Resources (km^3)': 'Water Resources (km^3)' + name})
    water_resources_gw_small= water_resources_gw_small.drop(["subresource"], axis = 1)
    water_resources_gw_short = pd.merge(base, water_resources_gw_small, on=['region', 'ssp', 'year', 'scenario'], how='outer').fillna(0)
    #electricity_full_cooling_1 = electricity_full_cooling.merge(electricity_full_small, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
    return  water_resources_gw_short

heading_list = gw_resources_full["subresource"].unique()
for i in range(1, len(heading_list)):
    print(i)
    water_resources_gw_short = make_small_dfs_water(heading_list[i], heading_list[i],  water_resources_gw_short)
    print(water_resources_gw_short)

elec_price_full = elec_price_full.loc[elec_price_full['fuel'] == 'electricity']
# Out:
# 4194
# 4206
# 4206
# 3653
# 4032
# 3852
# 3756
# 3456
# 2268
# 1
# 1980
#              scenario          region             subresource  year  \
# 0           Reference  Africa_Eastern  groundwater grade hist  1975
# 1           Reference  Africa_Eastern  groundwater grade hist  1990
# 2           Reference  Africa_Eastern  groundwater grade hist  2005
# 3           Reference  Africa_Eastern  groundwater grade hist  2010
# 4           Reference  Africa_Eastern  groundwater grade hist  2015
# ...               ...             ...                     ...   ...
# 3823  PolicyReference       Indonesia                       0  2080
# 3824  PolicyReference       Indonesia                       0  2085
# 3825  PolicyReference       Indonesia                       0  2090
# 3826  PolicyReference       Indonesia                       0  2095
# 3827  PolicyReference       Indonesia                       0  2100
#
#       Water Resources (km^3) grade hist  ssp  \
# ...

# %%
print(water_resources_gw_short.loc[water_resources_gw_short["region"] == "Africa_Eastern"])
# Out:
#              scenario          region             subresource  year  \
# 0           Reference  Africa_Eastern  groundwater grade hist  1975
# 1           Reference  Africa_Eastern  groundwater grade hist  1990
# 2           Reference  Africa_Eastern  groundwater grade hist  2005
# 3           Reference  Africa_Eastern  groundwater grade hist  2010
# 4           Reference  Africa_Eastern  groundwater grade hist  2015
# ...               ...             ...                     ...   ...
# 2877  PolicyReference  Africa_Eastern  groundwater grade hist  2080
# 2878  PolicyReference  Africa_Eastern  groundwater grade hist  2085
# 2879  PolicyReference  Africa_Eastern  groundwater grade hist  2090
# 2880  PolicyReference  Africa_Eastern  groundwater grade hist  2095
# 2881  PolicyReference  Africa_Eastern  groundwater grade hist  2100
#
#       Water Resources (km^3) grade hist  ssp  \
# 0                              0.000000    1
# 1                              0.000000    1
# ...

# %%
merge_test = electricity_full_cooling_1.merge(population_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test.loc[merge_test['region'] == 'USA'])
merge_test_2 = merge_test.merge(energy_consum_full_short, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_2.loc[merge_test_2['region'] == 'USA'])
merge_test_3 =merge_test_2
#merge_test_3 = merge_test_2.merge(food_consum_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_3.loc[merge_test_3['region'] == 'USA'])
merge_test_4 = merge_test_3.merge(food_price_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_4.loc[merge_test_4['region'] == 'USA'])
merge_test_5 = merge_test_4.merge(food_consum_by_type_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_5.loc[merge_test_5['region'] == 'USA'])
merge_test_6 = merge_test_5.merge(gdp_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_6.loc[merge_test_6['region'] == 'USA'])
merge_test_7 = merge_test_6.merge(water_resources_gw_short, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_7.loc[merge_test_7['region'] == 'USA'])
merge_test_8 = merge_test_7.merge(water_withdrawals_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_8.loc[merge_test_8['region'] == 'USA'])
merge_test_9 = merge_test_8.merge(water_consum_by_region_full_short, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_9.loc[merge_test_9['region'] == 'USA'])
merge_test_10 = merge_test_9.merge(gdp_total_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_10.loc[merge_test_10['region'] == 'USA'])
print(merge_test_10)
print('merge up to here correct')
merge_test_11 = merge_test_10.merge(elec_price_full, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year', 'scenario'])
print(merge_test_11.loc[merge_test_11['region'] == 'USA'])
print(merge_test_11)

#merge_test_11 = merge_test_10.merge(electricity_sum, left_on = ['region', 'ssp', 'year', 'scenario'], right_on = ['region', 'ssp', 'year','scenario'])
#print(merge_test_11)
# Out:
#              scenario region         sector         input  year  \
# 651         Reference    USA  resid cooling  elect_td_bld  1990
# 652         Reference    USA  resid cooling  elect_td_bld  2005
# 653         Reference    USA  resid cooling  elect_td_bld  2010
# 654         Reference    USA  resid cooling  elect_td_bld  2015
# 655         Reference    USA  resid cooling  elect_td_bld  2020
# ...               ...    ...            ...           ...   ...
# 4171        Reference    USA              0             0  1975
# 4184        Reference    USA              0             0  1975
# 4197        Reference    USA              0             0  1975
# 4210        Reference    USA              0             0  1975
# 4223  PolicyReference    USA              0             0  1975
#
#       Electricity Cooling (EJ)  ssp  Electricity (EJ)H2 central production  \
# 651                   0.605573    1                                    0.0
# ...

# %%
import geopandas

# %%
print(list(merge_test_11.columns.values))
# Out:
# ['scenario', 'region', 'sector', 'input_x', 'year', 'Electricity Cooling (EJ)', 'ssp', 'Electricity (EJ)H2 central production', 'Electricity (EJ)H2 industrial', 'Electricity (EJ)H2 liquid truck', 'Electricity (EJ)H2 pipeline', 'Electricity (EJ)H2 wholesale dispensing', 'Electricity (EJ)agricultural energy use', 'Electricity (EJ)cement', 'Electricity (EJ)comm cooling', 'Electricity (EJ)comm others', 'Electricity (EJ)construction energy use', 'Electricity (EJ)desalinated water', 'Electricity (EJ)industrial wastewater treatment', 'Electricity (EJ)industrial water abstraction', 'Electricity (EJ)industrial water treatment', 'Electricity (EJ)iron and steel', 'Electricity (EJ)irrigation water abstraction', 'Electricity (EJ)mining energy use', 'Electricity (EJ)municipal wastewater treatment', 'Electricity (EJ)municipal water abstraction', 'Electricity (EJ)municipal water distribution', 'Electricity (EJ)municipal water treatment', 'Electricity (EJ)other industrial energy use', 'Electricity (E
# ...

# %%
#DO NOT RUN- OLD TEST


#test metric 1: Price staple foods/GDP per capita
#$1.48 in Mar. 2005 equals $1 of buying power in 1990 (Average)
df= merge_test_10.copy()
df['Food Price (1990$/Mcal/day)'] = df['Food Price (2005$/Mcal/day)'] * (1/1.48)
#print(df['Food Price (1990$/Mcal/day)'])
#print(df['Food Price (2005$/Mcal/day)'])




df['Total GDP (1990$)'] = df['GDP (Million 1990$)'] * 1000000
df['Food Price Mcal/day / GDP'] = df['Food Price (1990$/Mcal/day)'] / df['Total GDP (1990$)'] 

df=df.loc[df['year'] == 2070]
df= df.loc[df['Food Price Staple/Nonstaple'] == 'FoodDemand_Staples']


df_1= df.drop(columns = ['scenario', 'sector', 'input_x', 'fuel_x', 'gcam-consumer', 'nodeinput', 'Food Price Staple/Nonstaple', 'sector_x', 'output_x', 'sector_y', 'output_y', 'account_x', 'subresource', 'input_y', 'input water consumption by region', 'account_y', 'fuel_y']

df_ssp1 = df_1.loc[df_1['ssp'] == 1]
df_ssp2 = df_1.loc[df_1['ssp'] == 2]
df_ssp3 = df_1.loc[df_1['ssp'] == 3]
df_ssp4 = df_1.loc[df_1['ssp'] == 4]
df_ssp5 = df_1.loc[df_1['ssp'] == 5]

df_ssp1=df_ssp1.groupby(["region"]).mean()
df_ssp2=df_ssp2.groupby(["region"]).mean()
df_ssp3=df_ssp3.groupby(["region"]).mean()
df_ssp4=df_ssp4.groupby(["region"]).mean()
df_ssp5=df_ssp5.groupby(["region"]).mean()


#move gdp to base level


#limit to staples only
# Out:
#   Cell In[10], line 21
#     df_1= df.drop(columns = ['scenario', 'sector', 'input_x', 'fuel_x', 'gcam-consumer', 'nodeinput', 'Food Price Staple/Nonstaple', 'sector_x', 'output_x', 'sector_y', 'output_y', 'account_x', 'subresource', 'input_y', 'input water consumption by region', 'account_y', 'fuel_y']
#                  ^
# SyntaxError: '(' was never closed

# %%
#DO NOT RUN- GEOPANDAS TEST


gdf = geopandas.read_file("region_boundaries_moirai_combined_3p1_0p5arcmin.shp")
gdf = gdf.set_index("reg_nm")
gdf["area"] = gdf.area
gdf["boundary"] = gdf.boundary



gdf['Food Price Mcal/day / GDP'] = df_ssp5['Food Price Mcal/day / GDP']
#separate column creation for water alone
plt.figure(figsize = (10,6))
gdf.plot('Food Price Mcal/day / GDP', legend=True, figsize = (10,6), cmap = "Spectral_r")

plt.title("Food Price Staples Mcal/day / GDP in 2070 (SSP5)")
plt.savefig("food_price_staples_to_gdp_indicator_ssp5.png")
# Out:
# C:\Users\cknox\AppData\Local\Temp\ipykernel_17720\2483625790.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area

# %%
#process the data.....

df= merge_test_11.copy()
df['Food Price (1990$/Mcal/day)'] = df['Food Price (2005$/Mcal/day)'] * (1/1.48)
df['Total GDP (1990$)'] = df['GDP (Million 1990$)'] * 1000000
#indicator 1
df['Food Price Mcal/day / GDP'] = df['Food Price (1990$/Mcal/day)'] / df['Total GDP (1990$)'] 
df['GDP/Food Price Mcal/day' ] =  df['Total GDP (1990$)'] /df['Food Price (1990$/Mcal/day)']
#indicator 2
df["ratio non staples to staples"] = df['Food Consumption By Type (Pcal) NonStaples'] / df['Food Consumption By Type (Pcal) Staples']
#indicator 3
df["food consumption per person"] = df["Total Food Consumption (Pcal)"]/(df["Population (Thousands)"] * 1000)
df["Total Residential Electricity Consumption (EJ)"] = df['Electricity Cooling (EJ)'] + df['Electricity (EJ)resid others']
df["Total Electricity Consumption Residential (kWh)"] = df["Total Residential Electricity Consumption (EJ)"] * (277777777777.77)
df["Residental Electricity consumption per capita (kWh pp)"]= df["Total Electricity Consumption Residential (kWh)"] /(df["Population (Thousands)"] * 1000)

elec_list = ['Electricity (EJ)H2 central production', 'Electricity (EJ)H2 industrial', 'Electricity (EJ)H2 liquid truck', 'Electricity (EJ)H2 pipeline', 'Electricity (EJ)H2 wholesale dispensing', 'Electricity (EJ)agricultural energy use', 'Electricity (EJ)cement', 'Electricity (EJ)comm cooling', 'Electricity (EJ)comm others', 'Electricity (EJ)construction energy use', 'Electricity (EJ)desalinated water', 'Electricity (EJ)industrial wastewater treatment', 'Electricity (EJ)industrial water abstraction', 'Electricity (EJ)industrial water treatment', 'Electricity (EJ)iron and steel', 'Electricity (EJ)irrigation water abstraction', 'Electricity (EJ)mining energy use', 'Electricity (EJ)municipal wastewater treatment', 'Electricity (EJ)municipal water abstraction', 'Electricity (EJ)municipal water distribution', 'Electricity (EJ)municipal water treatment', 'Electricity (EJ)other industrial energy use', 'Electricity (EJ)refining', 'Electricity (EJ)resid cooling', 'Electricity (EJ)resid others', 'Electricity (EJ)trn_aviation_intl', 'Electricity (EJ)trn_freight', 'Electricity (EJ)trn_freight_road', 'Electricity (EJ)trn_pass', 'Electricity (EJ)trn_pass_road', 'Electricity (EJ)trn_pass_road_LDV', 'Electricity (EJ)trn_pass_road_LDV_4W', 'Electricity (EJ)trn_shipping_intl', 'Electricity (EJ)aluminum', 'Electricity (EJ)chemical energy use', 'Electricity (EJ)comm heating', 'Electricity (EJ)resid heating']

df["Total Electricity Used (EJ)"] = df["Electricity Cooling (EJ)"]
for i in range(0, len(elec_list)):
    df["Total Electricity Used (EJ)"] = df["Total Electricity Used (EJ)"] + df[elec_list[i]]
df["Total Electricity Consumption Per Capita (kWh pp)"] = (df["Total Electricity Used (EJ)"] * 277777777777.77) / (df["Population (Thousands)"] * 1000)
#indicator 4
df["Electricity Availability"] = (df["Total Electricity Used (EJ)"] * 277777777777.77) / (4000 * (df["Population (Thousands)"] * 1000))
df['Total Energy Consumption (EJ)'] = df['Energy Consumption (EJ)a oil'] + df['Energy Consumption (EJ)b natural gas'] + df['Energy Consumption (EJ)c coal'] + df['Energy Consumption (EJ)d biomass'] + df['Energy Consumption (EJ)e nuclear'] + df['Energy Consumption (EJ)f hydro'] + df['Energy Consumption (EJ)g wind'] + df['Energy Consumption (EJ)h solar'] +df['Energy Consumption (EJ)i geothermal'] + df['Energy Consumption (EJ)j traditional biomass']
#indicator 6
df['Non-Biomass Ratio'] =  1 - (df['Energy Consumption (EJ)j traditional biomass'] / df['Total Energy Consumption (EJ)'])
df["Water Consumption per capita (L/day)"] = (df['Municipal Water Consumption (km^3)'] * 1000000000000) / (df["Population (Thousands)"] * 1000 * 365)
#indicator 7- normalized to 100 L instead of 200
df["Normalized Water Consumption Per Capita"] = df["Water Consumption per capita (L/day)"]/100
df["total groundwater use (km3)"] = df['Water Resources (km^3) grade hist'] + df['Water Resources (km^3)groundwater grade1'] + df['Water Resources (km^3)groundwater grade10'] + df['Water Resources (km^3)groundwater grade11'] + df['Water Resources (km^3)groundwater grade12'] + df['Water Resources (km^3)groundwater grade13'] + df['Water Resources (km^3)groundwater grade14'] +df['Water Resources (km^3)groundwater grade15'] +df['Water Resources (km^3)groundwater grade16'] +df['Water Resources (km^3)groundwater grade17'] + df['Water Resources (km^3)groundwater grade18'] +df['Water Resources (km^3)groundwater grade19'] +df['Water Resources (km^3)groundwater grade2'] +df['Water Resources (km^3)groundwater grade20']+ df['Water Resources (km^3)groundwater grade3'] +df['Water Resources (km^3)groundwater grade4'] +df['Water Resources (km^3)groundwater grade5'] +df['Water Resources (km^3)groundwater grade6'] +df['Water Resources (km^3)groundwater grade7'] +df['Water Resources (km^3)groundwater grade8'] +df['Water Resources (km^3)groundwater grade9']
df["total runoff use (km3)"] = df['Water Resources (km^3)runoff']
#indicator 8
df["Runoff to Groundwater Use"] = 1- (df["total groundwater use (km3)"]/ df["total runoff use (km3)"])
df["Electricity Price (1990$/GJ)"] = df['Electricity Price (1975$/GJ)'] * 2.43
#indicator 5
df["GDP/Electricity Price"] = df['Total GDP (1990$)'] /df["Electricity Price (1990$/GJ)"] 


#now we have each indicator- need to normalize
#must normalize indicators 1, 3, 4, 5, 6, 8

#normalize 1
#ind_1_min = df['Food Price Mcal/day / GDP'].min()
#ind_1_max = df['Food Price Mcal/day / GDP'].max()
#df['ind_1_norm'] = (df['Food Price Mcal/day / GDP'] - ind_1_min)/(ind_1_max - ind_1_min)
ind_1_min = df['GDP/Food Price Mcal/day'].min()
ind_1_max = df['GDP/Food Price Mcal/day'].max()
df['ind_1_norm'] = (df['GDP/Food Price Mcal/day' ] - ind_1_min)/(ind_1_max - ind_1_min)

#normalize 2
ind_2_min = df["ratio non staples to staples"].min()
ind_2_max = df["ratio non staples to staples"].max()
df['ind_2_norm'] = (df['ratio non staples to staples'] - ind_2_min)/(ind_2_max - ind_2_min)

#normalize 3
ind_3_min =df["food consumption per person"].min()
ind_3_max = df["food consumption per person"].max()
df['ind_3_norm'] = (df['food consumption per person'] - ind_3_min)/(ind_3_max - ind_3_min)

#normalize 4
ind_4_min = df["Electricity Availability"].min()
ind_4_max = df["Electricity Availability"].max()
df['ind_4_norm'] = (df['Electricity Availability'] - ind_4_min)/(ind_4_max - ind_4_min)


#normalize 5
ind_5_min = df["GDP/Electricity Price"].min()
ind_5_max = df["GDP/Electricity Price"].max()
df['ind_5_norm'] = (df['GDP/Electricity Price'] - ind_5_min)/(ind_5_max - ind_5_min)

#normalize 6
ind_6_min = df['Non-Biomass Ratio'].min()
ind_6_max = df['Non-Biomass Ratio'].max()
df['ind_6_norm'] = (df['Non-Biomass Ratio'] - ind_6_min)/(ind_6_max - ind_6_min)

#normalize 7
ind_7_min = df["Normalized Water Consumption Per Capita"].min()
ind_7_max = df["Normalized Water Consumption Per Capita"].max()
df['ind_7_norm'] = (df['Normalized Water Consumption Per Capita'] - ind_7_min)/(ind_7_max - ind_7_min)

#normalize 8
ind_8_min = df["Runoff to Groundwater Use"].min()
ind_8_max = df["Runoff to Groundwater Use"].max()
df['ind_8_norm'] = (df['Runoff to Groundwater Use'] - ind_8_min)/(ind_8_max - ind_8_min)

#index
#df['food_sub_indicator'] = (df['ind_1_norm'] * df['ind_2_norm'] *df['ind_3_norm']) ** (1/3)
#df['energy_sub_indicator'] = (df['ind_4_norm'] * df['ind_5_norm'] *df['ind_6_norm']) ** (1/3)
#df['water_sub_indicator'] = (df['ind_7_norm'] * df['ind_8_norm']) ** (1/2)
#df['FEW_index'] = (df['food_sub_indicator'] * df['energy_sub_indicator'] * df['water_sub_indicator']) ** (1/3) 

df['food_sub_indicator'] = (df['ind_1_norm'] * df['ind_2_norm'] *df['ind_3_norm']) ** (1/3)
print(df['food_sub_indicator'])
df['energy_sub_indicator'] = (df['ind_4_norm'] * df['ind_5_norm'] *df['ind_6_norm']) ** (1/3)
print(df['energy_sub_indicator'])
df['water_sub_indicator'] = (df['ind_7_norm'] * df['ind_8_norm']) ** (1/2)
print(df['water_sub_indicator'])
df['FEW_index'] = (df['food_sub_indicator'] * df['energy_sub_indicator'] * df['water_sub_indicator']) ** (1/3)
few_max = df['FEW_index'].max()
few_min = df["FEW_index"].min()
df["FEW index normalized"] = (df['FEW_index'] - few_min)/(few_max- few_min)
print(df["FEW index normalized"].max())
print(df["FEW index normalized"])
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 62995    0.423159
# 62996    0.423159
# 62997    0.423159
# 62998    0.423159
# 62999    0.423159
# Name: food_sub_indicator, Length: 63000, dtype: float64
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 62995    0.637863
# 62996    0.637863
# 62997    0.637863
# 62998    0.637863
# 62999    0.637863
# Name: energy_sub_indicator, Length: 63000, dtype: float64
# 0        0.045556
# 1        0.045556
# 2        0.045556
# 3        0.045556
# 4        0.045556
#            ...
# 62995    0.712212
# 62996    0.712212
# 62997    0.712212
# 62998    0.712212
# 62999    0.712212
# Name: water_sub_indicator, Length: 63000, dtype: float64
# 1.0
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 62995    0.698807
# 62996    0.698807
# ...

# %%
#make a function to generate figures
def make_maps(column_name, df_name, ssp, file_name, year, ssp_string):
    import matplotlib as mpl
    
    gdf = geopandas.read_file("region_boundaries_moirai_combined_3p1_0p5arcmin.shp")
    gdf = gdf.set_index("reg_nm")
    gdf["area"] = gdf.area
    gdf["boundary"] = gdf.boundary
    df_name = df_name.loc[df_name['ssp'] == ssp]
    df_name = df_name.loc[df_name['year'] == year]
    #df_name = df_name.drop(['Food Price Staple/Nonstaple','scenario', 'sector_x_x', 'input_x', 'fuel', 'sector_y_x', 'output', 'gcam-consumer', 'nodeinput', 'sector_x_y', 'output_x', 'sector_y_y', 'output_y', 'account_x', 'subresource', 'input_y',  'input water consumption by region', 'account_y'],  axis = 1)
    df_name= df_name.drop(columns = ['scenario', 'sector', 'input_x', 'fuel_x', 'gcam-consumer', 'nodeinput', 'Food Price Staple/Nonstaple', 'output_x', 'output_y', 'account_x', 'subresource', 'input_y', 'input water consumption by region', 'account_y', 'fuel_y'])
    df_name=df_name.groupby(["region"]).mean()
    gdf['Food Price Mcal/day / GDP'] = df_name[column_name]
    #separate column creation for water alone
    plt.figure(figsize = (10,6))
    gdf.plot('Food Price Mcal/day / GDP', legend=True, figsize = (10,6), cmap = "Spectral", norm=mpl.colors.CenteredNorm(vcenter = 0.5),legend_kwds={'shrink': 0.5})

    plt.title("Few_index in " + str(year)+ "(SSP " + ssp_string + ")" )
    plt.savefig(file_name)

#NEED TO MAKE SURE 'GOOD IS IN ONE DIRECTION!!!!!'




make_maps('FEW index normalized', df, 1, "Few_index_ssp1_2100.png", 2100, '1') 
#make_maps("Total Electricity Consumption Per Capita (kWh pp)", df, 1, "Total Electricity Consumption Per Capita (kWh pp)_ssp1.png", 2070, '1') 
make_maps('FEW index normalized', df, 3, "Few_index_ssp3_2100.png", 2100, '3') 
make_maps('FEW index normalized', df, 4, "Few_index_ssp4_2100.png", 2100, '4') 
make_maps('FEW index normalized', df, 5, "Few_index_ssp5_2100.png", 2100, '5') 
make_maps('FEW index normalized', df, 0, "Few_index_NDC_2100.png", 2100, 'NDC') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2100.png", 2100, '2') 




#print(df["Log Ratio Electricity"])
# Out:
# C:\Users\cknox\AppData\Local\Temp\ipykernel_32244\672247620.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area
# C:\Users\cknox\AppData\Local\Temp\ipykernel_32244\672247620.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area
# C:\Users\cknox\AppData\Local\Temp\ipykernel_32244\672247620.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area
# ...

# %%
print(df["Electricity Availability"])
make_maps("Total Electricity Consumption Per Capita (kWh pp)", df, 1, "Total Electricity Consumption Per Capita (kWh pp)_ssp1.png", 2070, '1') 


make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2020.png", 2020, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2025.png", 2025, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2030.png", 2030, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2035.png", 2035, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2040.png", 2040, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2045.png", 2045, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2050.png", 2050, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2055.png", 2055, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2060.png", 2060, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2065.png", 2065, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2070.png", 2070, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2075.png", 2075, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2080.png", 2080, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2085.png", 2085, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2090.png", 2090, '2') 
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2095.png", 2095, '2')
make_maps('FEW index normalized', df, 2, "Few_index_ssp2_2100.png", 2100, '2')
# Out:
# 0        0.016142
# 1        0.016142
# 2        0.016142
# 3        0.016142
# 4        0.016142
#            ...
# 62995    5.524180
# 62996    5.524180
# 62997    5.524180
# 62998    5.524180
# 62999    5.524180
# Name: Electricity Availability, Length: 63000, dtype: float64
# C:\Users\cknox\AppData\Local\Temp\ipykernel_37168\672247620.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area
# C:\Users\cknox\AppData\Local\Temp\ipykernel_37168\672247620.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area
# ...

# %%
#make figure with differences
df_new=df.copy()

df_new= df_new.drop(columns = ['scenario', 'sector', 'input_x', 'fuel_x', 'gcam-consumer', 'nodeinput', 'Food Price Staple/Nonstaple', 'output_x', 'output_y', 'account_x', 'subresource', 'input_y', 'input water consumption by region', 'account_y', 'fuel_y'])
df_new_ssp2 = df_new.loc[df_new['ssp'] == 2]
df_new_ssp2= df_new_ssp2.drop(columns = ['Electricity Cooling (EJ)','Electricity (EJ)H2 central production', 'Electricity (EJ)H2 industrial', 'Electricity (EJ)H2 liquid truck', 'Electricity (EJ)H2 pipeline', 'Electricity (EJ)H2 wholesale dispensing', 'Electricity (EJ)agricultural energy use', 'Electricity (EJ)cement', 'Electricity (EJ)comm cooling', 'Electricity (EJ)comm others', 'Electricity (EJ)construction energy use', 'Electricity (EJ)desalinated water', 'Electricity (EJ)industrial wastewater treatment', 'Electricity (EJ)industrial water abstraction', 'Electricity (EJ)industrial water treatment', 'Electricity (EJ)iron and steel', 'Electricity (EJ)irrigation water abstraction', 'Electricity (EJ)mining energy use', 'Electricity (EJ)municipal wastewater treatment', 'Electricity (EJ)municipal water abstraction', 'Electricity (EJ)municipal water distribution', 'Electricity (EJ)municipal water treatment', 'Electricity (EJ)other industrial energy use', 'Electricity (EJ)refining', 'Electricity (EJ)resid cooling', 'Electricity (EJ)resid others', 'Electricity (EJ)trn_aviation_intl', 'Electricity (EJ)trn_freight', 'Electricity (EJ)trn_freight_road', 'Electricity (EJ)trn_pass', 'Electricity (EJ)trn_pass_road', 'Electricity (EJ)trn_pass_road_LDV', 'Electricity (EJ)trn_pass_road_LDV_4W', 'Electricity (EJ)trn_shipping_intl', 'Electricity (EJ)aluminum', 'Electricity (EJ)chemical energy use', 'Electricity (EJ)comm heating', 'Electricity (EJ)resid heating', 'Electricity (EJ)CO2 removal', 'Population (Thousands)', 'Energy Consumption (EJ)a oil', 'Energy Consumption (EJ)b natural gas', 'Energy Consumption (EJ)c coal', 'Energy Consumption (EJ)d biomass', 'Energy Consumption (EJ)e nuclear', 'Energy Consumption (EJ)f hydro', 'Energy Consumption (EJ)g wind', 'Energy Consumption (EJ)h solar', 'Energy Consumption (EJ)i geothermal', 'Energy Consumption (EJ)j traditional biomass', 'Food Price (2005$/Mcal/day)', 'Food Consumption By Type (Pcal) NonStaples', 'Food Consumption By Type (Pcal) Staples', 'Total Food Consumption (Pcal)', 'GDP per capita (million 1990$)', 'Water Resources (km^3) grade hist', 'Water Resources (km^3)groundwater grade1', 'Water Resources (km^3)groundwater grade10', 'Water Resources (km^3)groundwater grade11', 'Water Resources (km^3)groundwater grade12', 'Water Resources (km^3)groundwater grade13', 'Water Resources (km^3)groundwater grade14', 'Water Resources (km^3)groundwater grade15', 'Water Resources (km^3)groundwater grade16', 'Water Resources (km^3)groundwater grade17', 'Water Resources (km^3)groundwater grade18', 'Water Resources (km^3)groundwater grade19', 'Water Resources (km^3)groundwater grade2', 'Water Resources (km^3)groundwater grade20', 'Water Resources (km^3)groundwater grade3', 'Water Resources (km^3)groundwater grade4', 'Water Resources (km^3)groundwater grade5', 'Water Resources (km^3)groundwater grade6', 'Water Resources (km^3)groundwater grade7', 'Water Resources (km^3)groundwater grade8', 'Water Resources (km^3)groundwater grade9', 'Water Resources (km^3)runoff', 'Water Withdrawals (km^3)', 'Municipal Water Consumption (km^3)', 'GDP (Million 1990$)', 'Electricity Price (1975$/GJ)', 'Food Price (1990$/Mcal/day)', 'Total GDP (1990$)', 'Food Price Mcal/day / GDP', 'GDP/Food Price Mcal/day', 'ratio non staples to staples', 'food consumption per person', 'Total Residential Electricity Consumption (EJ)', 'Total Electricity Consumption Residential (kWh)', 'Residental Electricity consumption per capita (kWh pp)', 'Total Electricity Used (EJ)', 'Total Electricity Consumption Per Capita (kWh pp)', 'Electricity Availability', 'Total Energy Consumption (EJ)', 'Non-Biomass Ratio', 'Water Consumption per capita (L/day)', 'Normalized Water Consumption Per Capita', 'total groundwater use (km3)', 'total runoff use (km3)', 'Runoff to Groundwater Use', 'Electricity Price (1990$/GJ)', 'GDP/Electricity Price', 'ind_1_norm', 'ind_2_norm', 'ind_3_norm', 'ind_4_norm', 'ind_5_norm', 'ind_6_norm', 'ind_7_norm', 'ind_8_norm'])
df_new_ssp2 = df_new_ssp2.rename(columns = {'FEW index normalized': 'FEW index normalized (SSP2)'})
df_new_ssp2 = df_new_ssp2.rename(columns = {'food_sub_indicator': 'food_sub_indicator (SSP2)'})
df_new_ssp2 = df_new_ssp2.rename(columns = {'energy_sub_indicator': 'energy_sub_indicator (SSP2)'})
df_new_ssp2 = df_new_ssp2.rename(columns = {'water_sub_indicator': 'water_sub_indicator (SSP2)'})
df_new_ssp2= df_new_ssp2.groupby(["region", "year"], as_index = False).mean()


df_new_ndc = df_new.loc[df_new['ssp'] == 0]                            
df_new_ndc= df_new_ndc.drop(columns = ['Electricity Cooling (EJ)','Electricity (EJ)H2 central production', 'Electricity (EJ)H2 industrial', 'Electricity (EJ)H2 liquid truck', 'Electricity (EJ)H2 pipeline', 'Electricity (EJ)H2 wholesale dispensing', 'Electricity (EJ)agricultural energy use', 'Electricity (EJ)cement', 'Electricity (EJ)comm cooling', 'Electricity (EJ)comm others', 'Electricity (EJ)construction energy use', 'Electricity (EJ)desalinated water', 'Electricity (EJ)industrial wastewater treatment', 'Electricity (EJ)industrial water abstraction', 'Electricity (EJ)industrial water treatment', 'Electricity (EJ)iron and steel', 'Electricity (EJ)irrigation water abstraction', 'Electricity (EJ)mining energy use', 'Electricity (EJ)municipal wastewater treatment', 'Electricity (EJ)municipal water abstraction', 'Electricity (EJ)municipal water distribution', 'Electricity (EJ)municipal water treatment', 'Electricity (EJ)other industrial energy use', 'Electricity (EJ)refining', 'Electricity (EJ)resid cooling', 'Electricity (EJ)resid others', 'Electricity (EJ)trn_aviation_intl', 'Electricity (EJ)trn_freight', 'Electricity (EJ)trn_freight_road', 'Electricity (EJ)trn_pass', 'Electricity (EJ)trn_pass_road', 'Electricity (EJ)trn_pass_road_LDV', 'Electricity (EJ)trn_pass_road_LDV_4W', 'Electricity (EJ)trn_shipping_intl', 'Electricity (EJ)aluminum', 'Electricity (EJ)chemical energy use', 'Electricity (EJ)comm heating', 'Electricity (EJ)resid heating', 'Electricity (EJ)CO2 removal', 'Population (Thousands)', 'Energy Consumption (EJ)a oil', 'Energy Consumption (EJ)b natural gas', 'Energy Consumption (EJ)c coal', 'Energy Consumption (EJ)d biomass', 'Energy Consumption (EJ)e nuclear', 'Energy Consumption (EJ)f hydro', 'Energy Consumption (EJ)g wind', 'Energy Consumption (EJ)h solar', 'Energy Consumption (EJ)i geothermal', 'Energy Consumption (EJ)j traditional biomass', 'Food Price (2005$/Mcal/day)', 'Food Consumption By Type (Pcal) NonStaples', 'Food Consumption By Type (Pcal) Staples', 'Total Food Consumption (Pcal)', 'GDP per capita (million 1990$)', 'Water Resources (km^3) grade hist', 'Water Resources (km^3)groundwater grade1', 'Water Resources (km^3)groundwater grade10', 'Water Resources (km^3)groundwater grade11', 'Water Resources (km^3)groundwater grade12', 'Water Resources (km^3)groundwater grade13', 'Water Resources (km^3)groundwater grade14', 'Water Resources (km^3)groundwater grade15', 'Water Resources (km^3)groundwater grade16', 'Water Resources (km^3)groundwater grade17', 'Water Resources (km^3)groundwater grade18', 'Water Resources (km^3)groundwater grade19', 'Water Resources (km^3)groundwater grade2', 'Water Resources (km^3)groundwater grade20', 'Water Resources (km^3)groundwater grade3', 'Water Resources (km^3)groundwater grade4', 'Water Resources (km^3)groundwater grade5', 'Water Resources (km^3)groundwater grade6', 'Water Resources (km^3)groundwater grade7', 'Water Resources (km^3)groundwater grade8', 'Water Resources (km^3)groundwater grade9', 'Water Resources (km^3)runoff', 'Water Withdrawals (km^3)', 'Municipal Water Consumption (km^3)', 'GDP (Million 1990$)', 'Electricity Price (1975$/GJ)', 'Food Price (1990$/Mcal/day)', 'Total GDP (1990$)', 'Food Price Mcal/day / GDP', 'GDP/Food Price Mcal/day', 'ratio non staples to staples', 'food consumption per person', 'Total Residential Electricity Consumption (EJ)', 'Total Electricity Consumption Residential (kWh)', 'Residental Electricity consumption per capita (kWh pp)', 'Total Electricity Used (EJ)', 'Total Electricity Consumption Per Capita (kWh pp)', 'Electricity Availability', 'Total Energy Consumption (EJ)', 'Non-Biomass Ratio', 'Water Consumption per capita (L/day)', 'Normalized Water Consumption Per Capita', 'total groundwater use (km3)', 'total runoff use (km3)', 'Runoff to Groundwater Use', 'Electricity Price (1990$/GJ)', 'GDP/Electricity Price', 'ind_1_norm', 'ind_2_norm', 'ind_3_norm', 'ind_4_norm', 'ind_5_norm', 'ind_6_norm', 'ind_7_norm', 'ind_8_norm'])
df_new_ndc = df_new_ndc.rename(columns = {'FEW index normalized': 'FEW index normalized (ndc)'})
df_new_ndc = df_new_ndc.rename(columns = {'food_sub_indicator': 'food_sub_indicator (ndc)'})
df_new_ndc = df_new_ndc.rename(columns = {'energy_sub_indicator': 'energy_sub_indicator (ndc)'})
df_new_ndc = df_new_ndc.rename(columns = {'water_sub_indicator': 'water_sub_indicator (ndc)'})
df_new_ndc= df_new_ndc.groupby(["region", "year"], as_index = False).mean()

merged_index = df_new_ssp2.merge(df_new_ndc, left_on = ['region', 'year'], right_on = ['region', 'year'])

merged_index["percent change"] = (merged_index['FEW index normalized (SSP2)'] - merged_index['FEW index normalized (ndc)']) / merged_index['FEW index normalized (SSP2)'] 
merged_index["percent change food sub-index"] = (merged_index['food_sub_indicator (SSP2)'] - merged_index['food_sub_indicator (ndc)']) / merged_index['food_sub_indicator (SSP2)'] 
merged_index["percent change energy sub-index"] = (merged_index['energy_sub_indicator (SSP2)'] - merged_index['energy_sub_indicator (ndc)']) / merged_index['energy_sub_indicator (SSP2)'] 
merged_index["percent change water sub-index"] = (merged_index['water_sub_indicator (SSP2)'] - merged_index['water_sub_indicator (ndc)']) / merged_index['water_sub_indicator (SSP2)'] 


def make_maps(column_name, df_name, file_name, year):
    import matplotlib as mpl
    gdf = geopandas.read_file("region_boundaries_moirai_combined_3p1_0p5arcmin.shp")
    gdf = gdf.set_index("reg_nm")
    gdf["area"] = gdf.area
    gdf["boundary"] = gdf.boundary
    df_name = df_name.loc[df_name['year'] == year]
    df_name=df_name.groupby(["region"]).mean()
    gdf['Food Price Mcal/day / GDP'] = df_name[column_name]
    #separate column creation for water alone
    plt.figure(figsize = (10,6))
    gdf.plot('Food Price Mcal/day / GDP', legend=True, figsize = (10,6), cmap = "Spectral_r", norm=mpl.colors.TwoSlopeNorm(vcenter = 0.15, vmin = -0.1, vmax = .4), legend_kwds={'shrink': 0.5})

    plt.title("Percent Decrease Food Sub-Index with Mitigation in " + str(year))
    plt.savefig(file_name)

#NEED TO MAKE SURE 'GOOD IS IN ONE DIRECTION!!!!!'

def add_region(x):
    if x == 'Africa_Eastern':
        return "Africa"
    elif x == "Africa_Northern":
        return "Africa"
    elif x == "Africa_Southern":
        return "Africa"
    elif x == "Africa_Western":
        return "Africa"
    elif x == "Argentina":
        return "South America"
    elif x == "Australia_NZ":
        return "Oceania"
    elif x == "Brazil":
        return "South America"
    elif x =="Canada":
        return "North America"
    elif x == "Central America and Caribbean":
        return "North America"
    elif x == "Central Asia":
        return "Asia"
    elif x == "China":
        return "Asia"
    elif x == "Colombia":
        return "South America"
    elif x == "EU-12":
        return "Europe"
    elif x == "EU-15":
        return "Europe"
    elif x == "Europe_Eastern":
        return "Europe"
    elif x == "Europe_Non_EU":
        return "Europe"
    elif x == "European Free Trade Association":
        return "Europe"
    elif x == "India":
        return "South Asia"
    elif x == "Indonesia":
        return "Asia"
    elif x == "Japan":
        return "Asia"
    elif x == "Mexico":
        return "North America"
    elif x == "Middle East":
        return "Middle East"
    elif x == "Pakistan":
        return "South Asia"
    elif x == "Russia":
        return "Russia"
    elif x == "South Africa":
        return "Africa"
    elif x == "South America_Northern":
        return "South America"
    elif x == "South America_Southern":
        return "South America"
    elif x == "South Asia":
        return "South Asia"
    elif x == "South Korea":
        return "Asia"
    elif x == "Southeast Asia":
        return "Asia"
    elif x == "Taiwan":
        return "Asia"
    elif x == "USA":
        return "North America"

df_new_ssp2["region color"] = 0
df_new_ndc["region color"] = 0

df_new_ssp2["region color"]= df_new_ssp2["region"].apply(add_region)
df_new_ndc["region color"]= df_new_ndc["region"].apply(add_region)
from matplotlib.pyplot import figure

#figure(figsize=(14, 10))
#sns.lineplot(data = df_new_ssp2, x = 'year', y = 'FEW index normalized (SSP2)', hue = "region color", alpha = 0.5, units="region", estimator=None)
#sns.lineplot(data = df_new_ndc, x = 'year', y = 'FEW index normalized (ndc)', hue = "region color", alpha = 0.5, linestyle = 'dashed', legend = False,units="region", estimator=None)
#plt.title("FEW Index With (Dashed) and Without (Solid) Mitigation")
#plt.legend(bbox_to_anchor=(1.00, 1.0))
#make_maps("percent change", merged_index, "percent_change_2100.png", 2100) 
make_maps("percent change food sub-index", merged_index, "percent_change_food_2100.png", 2100)
# Out:
# C:\Users\cknox02\AppData\Local\Temp\ipykernel_24200\2233552333.py:34: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["area"] = gdf.area

# %%
print(list(df_new_ssp2.columns.values))
# Out:
# ['region', 'year', 'ssp', 'FEW index normalized (SSP2)']
